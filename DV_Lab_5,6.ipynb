# %% [markdown]
# <a href="https://colab.research.google.com/github/Angelina1225/DV-Lab5/blob/master/DV_Lab_5%2C6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Iris dataset

# %%
# Load dataset
iris_df = pd.read_csv("/content/drive/MyDrive/iris.csv")
iris_df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris_df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.isnull()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris_df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
iris_df.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'species']
iris_df
# Out:
#      sepal length  sepal width  petal length  petal width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal length', y='sepal width', hue='species', data=iris_df)
plt.show()

# %%
sns.scatterplot(x='petal length', y='petal width', hue='species', data=iris_df)
plt.show()

# %% [markdown]
# The scatter plot matrix can be plotted using 3 tools: Pandas, Seaborn and Plotly.express. Scatter plot matrix is plotted using all the 3 tools below.

# %%
# Scatter plot matrix using Pandas
colors = {"Setosa":'orange', "Virginica":'red', "Versicolor":'green'}
f = pd.plotting.scatter_matrix(iris_df,figsize=(15,15),grid=True, marker='^', color=iris_df['species'].map(colors))

# %%
# Scatter plot matrix using plotly.express
f = px.scatter_matrix(iris_df)
f.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
g = px.scatter_matrix(iris_df,
    dimensions=iris_df.columns[0:4],
    color="species", symbol="species",
    labels=iris_df.columns) 
g.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py:5069: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
# Scatter plot matrix using Seaborn
sns.set_theme(style="ticks")
sns.pairplot(iris_df, hue='species')

# %%
corr = iris_df.corr()
print(corr)
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.117570      0.871754     0.817941
# sepal width      -0.117570     1.000000     -0.428440    -0.366126
# petal length      0.871754    -0.428440      1.000000     0.962865
# petal width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# From the above scatter plot matrix and the correlation coeffients we can observe that:
# *   Petal length and petal width are strongly positively correlated, with a correlation coefficient of 0.96.
# *   Sepal length and petal length appear to be positively correlated, with a correlation coefficient of 0.87.
# *   Sepal length and petal width also appear to be positively correlated, with a correlation coefficient of 0.82.
# *   Sepal width does not appear to be strongly correlated with any of the other variables but is negatively correlated with all the variables.

# %% [markdown]
# **Which classes is linearly seperable?**
#
# Of all the three classes i.e Setosa, Versicolor and Virginica, from the plotted scatterplot matrix we can observe that the ***Setosa*** class appears to be linealy separable from the remaining two classes i.e. Versicolor and virginica as it can be clearly seperated from the remaining two classes in all the plots

# %% [markdown]
# # Adult income dataset

# %%
columns = ['age','workclass','fnlwgt','education','edu-num','marital-status','occupation','relationship','race','sex','gain','loss','hours per week','citizenship','income']

# %%
# Load dataset
adult_df = pd.read_csv("/content/drive/MyDrive/adult.csv", names = columns, sep=',', skipinitialspace = True)
adult_df
# Out:
#        age         workclass  fnlwgt   education  edu-num      marital-status  \
# 0       39         State-gov   77516   Bachelors       13       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors       13  Married-civ-spouse
# 2       38           Private  215646     HS-grad        9            Divorced
# 3       53           Private  234721        11th        7  Married-civ-spouse
# 4       28           Private  338409   Bachelors       13  Married-civ-spouse
# ...    ...               ...     ...         ...      ...                 ...
# 32556   27           Private  257302  Assoc-acdm       12  Married-civ-spouse
# 32557   40           Private  154374     HS-grad        9  Married-civ-spouse
# 32558   58           Private  151910     HS-grad        9             Widowed
# 32559   22           Private  201490     HS-grad        9       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad        9  Married-civ-spouse
#
# ...

# %%
adult_df.shape
# Out:
# (32561, 15)

# %%
print(f"No. of rows : {adult_df.shape[0]}")
print(f"No. of columns : {adult_df.shape[1]}")
# Out:
# No. of rows : 32561
# No. of columns : 15

# %%
adult_df.head()
# Out:
#    age         workclass  fnlwgt  education  edu-num      marital-status  \
# 0   39         State-gov   77516  Bachelors       13       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors       13  Married-civ-spouse
# 2   38           Private  215646    HS-grad        9            Divorced
# 3   53           Private  234721       11th        7  Married-civ-spouse
# 4   28           Private  338409  Bachelors       13  Married-civ-spouse
#
#           occupation   relationship   race     sex  gain  loss  \
# 0       Adm-clerical  Not-in-family  White    Male  2174     0
# 1    Exec-managerial        Husband  White    Male     0     0
# 2  Handlers-cleaners  Not-in-family  White    Male     0     0
# 3  Handlers-cleaners        Husband  Black    Male     0     0
# 4     Prof-specialty           Wife  Black  Female     0     0
#
#    hours per week    citizenship income
# 0              40  United-States  <=50K
# 1              13  United-States  <=50K
# ...

# %%
adult_df.tail()
# Out:
#        age     workclass  fnlwgt   education  edu-num      marital-status  \
# 32556   27       Private  257302  Assoc-acdm       12  Married-civ-spouse
# 32557   40       Private  154374     HS-grad        9  Married-civ-spouse
# 32558   58       Private  151910     HS-grad        9             Widowed
# 32559   22       Private  201490     HS-grad        9       Never-married
# 32560   52  Self-emp-inc  287927     HS-grad        9  Married-civ-spouse
#
#               occupation relationship   race     sex   gain  loss  \
# 32556       Tech-support         Wife  White  Female      0     0
# 32557  Machine-op-inspct      Husband  White    Male      0     0
# 32558       Adm-clerical    Unmarried  White  Female      0     0
# 32559       Adm-clerical    Own-child  White    Male      0     0
# 32560    Exec-managerial         Wife  White  Female  15024     0
#
#        hours per week    citizenship income
# 32556              38  United-States  <=50K
# ...

# %%
adult_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   edu-num         32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  gain            32561 non-null  int64
#  11  loss            32561 non-null  int64
#  12  hours per week  32561 non-null  int64
#  13  citizenship     32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult_df.describe()
# Out:
#                 age        fnlwgt       edu-num          gain          loss  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        hours per week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adult_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# edu-num            int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# gain               int64
# loss               int64
# hours per week     int64
# citizenship       object
# income            object
# dtype: object

# %%
adult_df.isnull()
# Out:
#          age  workclass  fnlwgt  education  edu-num  marital-status  \
# 0      False      False   False      False    False           False
# 1      False      False   False      False    False           False
# 2      False      False   False      False    False           False
# 3      False      False   False      False    False           False
# 4      False      False   False      False    False           False
# ...      ...        ...     ...        ...      ...             ...
# 32556  False      False   False      False    False           False
# 32557  False      False   False      False    False           False
# 32558  False      False   False      False    False           False
# 32559  False      False   False      False    False           False
# 32560  False      False   False      False    False           False
#
#        occupation  relationship   race    sex   gain   loss  hours per week  \
# ...

# %%
adult_df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# edu-num           0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# gain              0
# loss              0
# hours per week    0
# citizenship       0
# income            0
# dtype: int64

# %%
adult_df.isin(['?'])
# Out:
#          age  workclass  fnlwgt  education  edu-num  marital-status  \
# 0      False      False   False      False    False           False
# 1      False      False   False      False    False           False
# 2      False      False   False      False    False           False
# 3      False      False   False      False    False           False
# 4      False      False   False      False    False           False
# ...      ...        ...     ...        ...      ...             ...
# 32556  False      False   False      False    False           False
# 32557  False      False   False      False    False           False
# 32558  False      False   False      False    False           False
# 32559  False      False   False      False    False           False
# 32560  False      False   False      False    False           False
#
#        occupation  relationship   race    sex   gain   loss  hours per week  \
# ...

# %%
adult_df.isin(['?']).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# edu-num              0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# gain                 0
# loss                 0
# hours per week       0
# citizenship        583
# income               0
# dtype: int64

# %%
null = adult_df.isin(['?']).sum() * 100 / len(adult_df)
null
# Out:
# age               0.000000
# workclass         5.638647
# fnlwgt            0.000000
# education         0.000000
# edu-num           0.000000
# marital-status    0.000000
# occupation        5.660146
# relationship      0.000000
# race              0.000000
# sex               0.000000
# gain              0.000000
# loss              0.000000
# hours per week    0.000000
# citizenship       1.790486
# income            0.000000
# dtype: float64

# %%
sns.heatmap(adult_df.isin(['?']))
plt.show()

# %%
adult_df['workclass'] = adult_df['workclass'].replace('?', np.nan)
adult_df['occupation'] = adult_df['occupation'].replace('?', np.nan)
adult_df['citizenship'] = adult_df['citizenship'].replace('?', np.nan)

# %%
adult_df.isin(['?']).sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# edu-num           0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# gain              0
# loss              0
# hours per week    0
# citizenship       0
# income            0
# dtype: int64

# %%
adult_df.duplicated().sum()
# Out:
# 24

# %%
adult_df = adult_df.drop_duplicates()
adult_df.duplicated().sum()
# Out:
# 0

# %%
adult_df.shape
# Out:
# (32537, 15)

# %%
# List of numerical attributes
num_attr = adult_df.select_dtypes(include=['int'])
num_attr
# Out:
#        age  fnlwgt  edu-num   gain  loss  hours per week
# 0       39   77516       13   2174     0              40
# 1       50   83311       13      0     0              13
# 2       38  215646        9      0     0              40
# 3       53  234721        7      0     0              40
# 4       28  338409       13      0     0              40
# ...    ...     ...      ...    ...   ...             ...
# 32556   27  257302       12      0     0              38
# 32557   40  154374        9      0     0              40
# 32558   58  151910        9      0     0              40
# 32559   22  201490        9      0     0              20
# 32560   52  287927        9  15024     0              40
#
# [32537 rows x 6 columns]

# %%
# Histograms of the numerical attributes
num_attr.hist(figsize=(12,15))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'fnlwgt'}>],
#        [<Axes: title={'center': 'edu-num'}>,
#         <Axes: title={'center': 'gain'}>],
#        [<Axes: title={'center': 'loss'}>,
#         <Axes: title={'center': 'hours per week'}>]], dtype=object)

# %%
num_attr.describe()
# Out:
#                 age        fnlwgt       edu-num          gain          loss  \
# count  32537.000000  3.253700e+04  32537.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05     10.081815   1078.443741     87.368227
# std       13.637984  1.055565e+05      2.571633   7387.957424    403.101833
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        hours per week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# List of categorical attributes
cat_attr = adult_df.select_dtypes(include=['object'])
cat_attr
# Out:
#               workclass   education      marital-status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex    citizenship income
# ...

# %%
cat_attr.isin(['?']).sum()
# Out:
# workclass         0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# citizenship       0
# income            0
# dtype: int64

# %%
cat_attr.isin(['?']).sum()
# Out:
# workclass         0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# citizenship       0
# income            0
# dtype: int64

# %% [markdown]
# Count plots of the categorical attributes

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = cat_attr, x = 'workclass')
# Out:
# <Axes: xlabel='workclass', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
sns.countplot(data = cat_attr, x = 'education')
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data = cat_attr, x = 'marital-status')
# Out:
# <Axes: xlabel='marital-status', ylabel='count'>

# %%
plt.figure(figsize=(25,8))
sns.countplot(data = cat_attr, x = 'occupation')
# Out:
# <Axes: xlabel='occupation', ylabel='count'>

# %%
plt.figure(figsize=(3,5))
sns.countplot(data = cat_attr, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
cat_attr.describe()
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      30701     32537               32537           30694        32537
# unique         8        16                   7              14            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22673     10494               14970            4136        13187
#
#          race    sex    citizenship income
# count   32537  32537          31955  32537
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    27795  21775          29153  24698

# %%
# Relation between Income and Age
sns.catplot(data=adult_df, x='income', y='age', kind= 'box', aspect=2)
plt.title('Relationship between Income and Age')
plt.show()

# %%
adult_df.replace(to_replace=['<=50K', '>50K'], value=[0, 1], inplace=True)
# Out:
# <ipython-input-135-895fd5633f26>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Who has more income
adult_df.groupby('workclass')['income'].mean().sort_values(ascending= False)
# Out:
# workclass
# Self-emp-inc        0.557348
# Federal-gov         0.386458
# Local-gov           0.294792
# Self-emp-not-inc    0.285039
# State-gov           0.271957
# Private             0.218807
# Never-worked        0.000000
# Without-pay         0.000000
# Name: income, dtype: float64

# %%
adult_df.groupby('sex')['income'].mean().sort_values(ascending=False)
# Out:
# sex
# Male      0.305855
# Female    0.109552
# Name: income, dtype: float64

# %%
corr = adult_df.corr()
f, ax = plt.subplots(figsize=(10, 12))
cmap =  sns.diverging_palette (220, 10, as_cmap=True)
sns.heatmap(corr, square=True, ax = ax, annot=True, linewidth = 0.1)

plt.title("Correlation of features", y=1.05, size=15)
# Out:
# Text(0.5, 1.05, 'Correlation of features')
